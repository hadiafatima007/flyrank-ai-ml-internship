# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
""" 
Lane: Robotics & Intelligent Systems

ML Task Type: Classification

The goal is to predict whether a robot will successfully complete a task based on observed sensor readings and measured system conditions. 
Since the output belongs to one of two categories (Success or Failure), this is a classification problem."""
# Out:
# ' \nLane: Robotics & Intelligent Systems\n\nML Task Type: Classification\n\nThe goal is to predict whether a robot will successfully complete a task based on observed sensor readings and measured system conditions. \nSince the output belongs to one of two categories (Success or Failure), this is a classification problem.'

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
"""
Target:Task Completion Status

Possible values:
• Success
• Failure

The target label is the observed outcome after the robot completes a task. The outcome is recorded as Success or Failure."""
# Out:
# '\nTarget:Task Completion Status\n\nPossible values:\n• Success\n• Failure\n\nThe target label is the observed outcome after the robot completes a task. The outcome is recorded as Success or Failure.'

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
"""
Success Metric: Accuracy

Model performance is measured using accuracy. 
A value above 90% would indicate good predictive performance on the available dataset."""
# Out:
# '\nSuccess Metric: Accuracy\n\nModel performance is measured using accuracy. \nA value above 90% would indicate good predictive performance on the available dataset.'

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd
df = pd.DataFrame({
    "Robot_ID": ["R001", "R002", "R003"],
    "Battery": [95, 61, 88],
    "Distance_cm": [42, 15, 55],
    "Motor Current_A": [1.8, 2.9, 1.6],
    "Speed_mps": [0.75, 0.60, 0.82],
    "IMU_Tilt_deg": [3.1, 8.7, 2.4],
    "Task_Result": ["Success", "Failure", "Success"]
})

df
# Out:
#   Robot_ID  Battery  Distance_cm  Motor Current_A  Speed_mps  IMU_Tilt_deg  \
# 0     R001       95           42              1.8       0.75           3.1
# 1     R002       61           15              2.9       0.60           8.7
# 2     R003       88           55              1.6       0.82           2.4
#
#   Task_Result
# 0     Success
# 1     Failure
# 2     Success

# %%
"""Each row represents one robot task attempt. 
The input features are sensor measurements and operating conditions, while the target column is the observed task result."""
# Out:
# 'Each row represents one robot task attempt. \nThe input features are sensor measurements and operating conditions, while the target column is the observed task result.'

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
"""
Robot performance depends on multiple observed sensor readings that interact in complex ways. 
A fixed rule cannot capture every possible situation, such as changes in battery level, motor load, sensor noise, or environmental conditions. 
Machine learning learns patterns from historical data to provide decision support by predicting task outcomes under varying operating conditions.
"""
# Out:
# '\nRobot performance depends on multiple observed sensor readings that interact in complex ways. \nA fixed rule cannot capture every possible situation, such as changes in battery level, motor load, sensor noise, or environmental conditions. \nMachine learning learns patterns from historical data to provide decision support by predicting task outcomes under varying operating conditions.\n'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
